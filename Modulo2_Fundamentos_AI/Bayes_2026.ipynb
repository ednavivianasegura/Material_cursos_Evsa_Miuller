# %% [markdown]
# <a href="https://colab.research.google.com/github/ednavivianasegura/Curso_ML_Python/blob/main/Modulo2_Fundamentos_AI/Bayes_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ednavivianasegura/ERAP_CursoPython.git

# %%
import os
os.chdir("/content/ERAP_CursoPython/Modulo2_Fundamentos_AI")

# %%
# @title
# %%html

<!-- TÍTULO -->

<div align="center" style="margin-top:40px; margin-bottom:30px;">

<h1 style="
color:#1E3A8A;
font-size:62px;
font-family:Arial;
font-weight:800;
margin-bottom:10px;
">
🧠 Clasificadores Bayesianos
</h1>

<p style="
color:#475569;
font-size:24px;
font-family:Arial;
">
Probabilidad, inferencia y toma de decisiones
</p>

</div>

<!-- INTRODUCCIÓN -->

<div style="
width:85%;
margin:auto;
font-family:Arial;
line-height:1.9;
font-size:22px;
color:#475569;
">

<p>
Los clasificadores bayesianos utilizan principios de probabilidad para estimar
la clase más probable de una observación a partir de los datos disponibles.
Su fundamento matemático proviene del
<strong style="color:#0F766E;">Teorema de Bayes</strong>,
una de las herramientas más importantes en estadística, machine learning e inferencia probabilística.
</p>

<p>
La idea central consiste en actualizar nuestras creencias sobre una clase
utilizando nueva evidencia observada.
</p>

</div>

<!-- ECUACIÓN -->

<div align="center" style="margin-top:55px;">

<h2 style="
color:#1E3A8A;
font-size:42px;
font-family:Arial;
font-weight:800;
margin-bottom:30px;
">
📐 Teorema de Bayes
</h2>

</div>

<div align="center" style="
width:82%;
margin:auto;
padding:45px;
background:linear-gradient(135deg,#F8FAFC,#EEF2FF);
border-radius:26px;
box-shadow:0px 5px 20px rgba(0,0,0,0.08);
">

<div style="
font-size:42px;
font-family:'Times New Roman', serif;
font-weight:700;
color:#0F766E;
line-height:2;
">

P(Cₖ | x)

<span style="
display:inline-block;
vertical-align:middle;
margin:0px 18px;
font-size:50px;
color:#1E3A8A;
">
=
</span>

<div style="
display:inline-block;
vertical-align:middle;
text-align:center;
">

<div style="
border-bottom:3px solid #0F766E;
padding:0px 18px 10px 18px;
">
P(x | Cₖ) · P(Cₖ)
</div>

<div style="
padding-top:10px;
">
P(x)
</div>

</div>

</div>

<p style="
margin-top:28px;
font-size:20px;
font-family:Arial;
color:#64748B;
line-height:1.8;
">

El teorema permite calcular la probabilidad de una clase utilizando evidencia observada.

</p>

</div>

<!-- INTERPRETACIÓN -->

<div align="center" style="margin-top:70px;">

<h2 style="
color:#1E3A8A;
font-size:40px;
font-family:Arial;
font-weight:800;
margin-bottom:28px;
">
⚡ Interpretación de los Componentes
</h2>

</div>

<div align="center">

<table style="
border-collapse:collapse;
font-family:Arial;
font-size:22px;
min-width:920px;
box-shadow:0px 4px 16px rgba(0,0,0,0.08);
border-radius:16px;
overflow:hidden;
">

<tr style="
background-color:#1E3A8A;
color:white;
">
<th style="padding:18px;">Elemento</th>
<th style="padding:18px;">Significado</th>
</tr>

<tr style="background-color:#F8FAFC;">
<td style="
padding:18px;
font-weight:700;
color:#0F766E;
">
P(Cₖ | x)
</td>

<td style="
padding:18px;
color:#475569;
line-height:1.7;
">
Probabilidad posterior de que la observación pertenezca a la clase Cₖ
después de observar los datos.
</td>
</tr>

<tr style="background-color:white;">
<td style="
padding:18px;
font-weight:700;
color:#0F766E;
">
P(x | Cₖ)
</td>

<td style="
padding:18px;
color:#475569;
line-height:1.7;
">
Verosimilitud: probabilidad de observar x suponiendo que pertenece a la clase Cₖ.
</td>
</tr>

<tr style="background-color:#F8FAFC;">
<td style="
padding:18px;
font-weight:700;
color:#0F766E;
">
P(Cₖ)
</td>

<td style="
padding:18px;
color:#475569;
line-height:1.7;
">
Probabilidad previa de la clase antes de observar los datos.
</td>
</tr>

<tr style="background-color:white;">
<td style="
padding:18px;
font-weight:700;
color:#0F766E;
">
P(x)
</td>

<td style="
padding:18px;
color:#475569;
line-height:1.7;
">
Probabilidad total de observar x. Actúa como un factor de normalización.
</td>
</tr>

</table>

</div>

<!-- IDEA CENTRAL -->

<div align="center" style="
margin-top:70px;
padding:38px;
width:82%;
margin-left:auto;
margin-right:auto;
background:linear-gradient(135deg,#F8FAFC,#F1F5F9);
border-radius:24px;
box-shadow:0px 4px 16px rgba(0,0,0,0.08);
">

<h2 style="
color:#1E3A8A;
font-size:38px;
font-family:Arial;
font-weight:800;
margin-bottom:20px;
">
🎯 Regla de Clasificación
</h2>

<p style="
color:#475569;
font-size:24px;
font-family:Arial;
line-height:1.9;
">

Para clasificar una nueva observación, el modelo calcula la probabilidad posterior
de cada clase y selecciona aquella con el valor más alto.

</p>

<div style="
margin-top:28px;
font-size:36px;
font-family:'Times New Roman', serif;
font-weight:700;
color:#0F766E;
">

Clase Predicha = argmax P(Cₖ | x)

</div>

</div>

<!-- APLICACIONES -->

<div align="center" style="margin-top:70px;">

<h2 style="
color:#1E3A8A;
font-size:40px;
font-family:Arial;
font-weight:800;
margin-bottom:30px;
">
🚀 Aplicaciones Comunes
</h2>

</div>

<div align="center" style="
display:flex;
justify-content:center;
gap:25px;
flex-wrap:wrap;
width:90%;
margin:auto;
">

<div style="
background:#F8FAFC;
padding:28px;
border-radius:20px;
width:250px;
box-shadow:0px 4px 14px rgba(0,0,0,0.08);
">

<div style="font-size:46px;">📧</div>

<h3 style="
color:#1E3A8A;
font-family:Arial;
margin-top:15px;
">
Filtrado de Spam
</h3>

<p style="
color:#475569;
font-size:18px;
line-height:1.7;
">
Clasificación automática de correos legítimos y no deseados.
</p>

</div>

<div style="
background:#F8FAFC;
padding:28px;
border-radius:20px;
width:250px;
box-shadow:0px 4px 14px rgba(0,0,0,0.08);
">

<div style="font-size:46px;">🩺</div>

<h3 style="
color:#1E3A8A;
font-family:Arial;
margin-top:15px;
">
Diagnóstico Médico
</h3>

<p style="
color:#475569;
font-size:18px;
line-height:1.7;
">
Estimación probabilística de enfermedades a partir de síntomas.
</p>

</div>

<div style="
background:#F8FAFC;
padding:28px;
border-radius:20px;
width:250px;
box-shadow:0px 4px 14px rgba(0,0,0,0.08);
">

<div style="font-size:46px;">💬</div>

<h3 style="
color:#1E3A8A;
font-family:Arial;
margin-top:15px;
">
Procesamiento de Texto
</h3>

<p style="
color:#475569;
font-size:18px;
line-height:1.7;
">
Clasificación de documentos, sentimientos y lenguaje natural.
</p>

</div>

</div>
# Out:
# <!-- TÍTULO -->
#
# <div align="center" style="margin-top:40px; margin-bottom:30px;">
#
# <h1 style="
# color:#1E3A8A;
# font-size:62px;
# font-family:Arial;
# font-weight:800;
# margin-bottom:10px;
# ">
# 🧠 Clasificadores Bayesianos
# </h1>
#
# <p style="
# color:#475569;
# font-size:24px;
# font-family:Arial;
# ">
# Probabilidad, inferencia y toma de decisiones
# </p>
#
# </div>
#
# <!-- INTRODUCCIÓN -->
#
# <div style="
# width:85%;
# margin:auto;
# font-family:Arial;
# line-height:1.9;
# font-size:22px;
# color:#475569;
# ">
#
# <p>
# Los clasificadores bayesianos utilizan principios de probabilidad para estimar
# la clase más probable de una observación a partir de los datos disponibles.
# Su fundamento matemático proviene del
# <strong style="color:#0F766E;">Teorema de Bayes</strong>,
# una de las herramientas más importantes en estadística, machine learning e inferencia probabilística.
# </p>
#
# <p>
# La idea central consiste en actualizar nuestras creencias sobre una clase
# utilizando nueva evidencia observada.
# </p>
#
# </div>
#
# <!-- ECUACIÓN -->
#
# <div align="center" style="margin-top:55px;">
#
# <h2 style="
# color:#1E3A8A;
# font-size:42px;
# font-family:Arial;
# font-weight:800;
# margin-bottom:30px;
# ">
# 📐 Teorema de Bayes
# </h2>
#
# </div>
#
# <div align="center" style="
# width:82%;
# margin:auto;
# padding:45px;
# background:linear-gradient(135deg,#F8FAFC,#EEF2FF);
# border-radius:26px;
# box-shadow:0px 5px 20px rgba(0,0,0,0.08);
# ">
#
# <div style="
# font-size:42px;
# font-family:'Times New Roman', serif;
# font-weight:700;
# color:#0F766E;
# line-height:2;
# ">
#
# P(Cₖ | x)
#
# <span style="
# display:inline-block;
# vertical-align:middle;
# margin:0px 18px;
# font-size:50px;
# color:#1E3A8A;
# ">
# =
# </span>
#
# <div style="
# display:inline-block;
# vertical-align:middle;
# text-align:center;
# ">
#
# <div style="
# border-bottom:3px solid #0F766E;
# padding:0px 18px 10px 18px;
# ">
# P(x | Cₖ) · P(Cₖ)
# </div>
#
# <div style="
# padding-top:10px;
# ">
# P(x)
# </div>
#
# </div>
#
# </div>
#
# <p style="
# margin-top:28px;
# font-size:20px;
# font-family:Arial;
# color:#64748B;
# line-height:1.8;
# ">
#
# El teorema permite calcular la probabilidad de una clase utilizando evidencia observada.
#
# </p>
#
# </div>
#
# <!-- INTERPRETACIÓN -->
#
# <div align="center" style="margin-top:70px;">
#
# <h2 style="
# color:#1E3A8A;
# font-size:40px;
# font-family:Arial;
# font-weight:800;
# margin-bottom:28px;
# ">
# ⚡ Interpretación de los Componentes
# </h2>
#
# </div>
#
# <div align="center">
#
# <table style="
# border-collapse:collapse;
# font-family:Arial;
# font-size:22px;
# min-width:920px;
# box-shadow:0px 4px 16px rgba(0,0,0,0.08);
# border-radius:16px;
# overflow:hidden;
# ">
#
# <tr style="
# background-color:#1E3A8A;
# color:white;
# ">
# <th style="padding:18px;">Elemento</th>
# <th style="padding:18px;">Significado</th>
# </tr>
#
# <tr style="background-color:#F8FAFC;">
# <td style="
# padding:18px;
# font-weight:700;
# color:#0F766E;
# ">
# P(Cₖ | x)
# </td>
#
# <td style="
# padding:18px;
# color:#475569;
# line-height:1.7;
# ">
# Probabilidad posterior de que la observación pertenezca a la clase Cₖ
# después de observar los datos.
# </td>
# </tr>
#
# <tr style="background-color:white;">
# <td style="
# padding:18px;
# font-weight:700;
# color:#0F766E;
# ">
# P(x | Cₖ)
# </td>
#
# <td style="
# padding:18px;
# color:#475569;
# line-height:1.7;
# ">
# Verosimilitud: probabilidad de observar x suponiendo que pertenece a la clase Cₖ.
# </td>
# </tr>
#
# <tr style="background-color:#F8FAFC;">
# <td style="
# padding:18px;
# font-weight:700;
# color:#0F766E;
# ">
# P(Cₖ)
# </td>
#
# <td style="
# padding:18px;
# color:#475569;
# line-height:1.7;
# ">
# Probabilidad previa de la clase antes de observar los datos.
# </td>
# </tr>
#
# <tr style="background-color:white;">
# <td style="
# padding:18px;
# font-weight:700;
# color:#0F766E;
# ">
# P(x)
# </td>
#
# <td style="
# padding:18px;
# color:#475569;
# line-height:1.7;
# ">
# Probabilidad total de observar x. Actúa como un factor de normalización.
# </td>
# </tr>
#
# </table>
#
# </div>
#
# <!-- IDEA CENTRAL -->
#
# <div align="center" style="
# margin-top:70px;
# padding:38px;
# width:82%;
# margin-left:auto;
# margin-right:auto;
# background:linear-gradient(135deg,#F8FAFC,#F1F5F9);
# border-radius:24px;
# box-shadow:0px 4px 16px rgba(0,0,0,0.08);
# ">
#
# <h2 style="
# color:#1E3A8A;
# font-size:38px;
# font-family:Arial;
# font-weight:800;
# margin-bottom:20px;
# ">
# 🎯 Regla de Clasificación
# </h2>
#
# <p style="
# color:#475569;
# font-size:24px;
# font-family:Arial;
# line-height:1.9;
# ">
#
# Para clasificar una nueva observación, el modelo calcula la probabilidad posterior
# de cada clase y selecciona aquella con el valor más alto.
#
# </p>
#
# <div style="
# margin-top:28px;
# font-size:36px;
# font-family:'Times New Roman', serif;
# font-weight:700;
# color:#0F766E;
# ">
#
# Clase Predicha = argmax P(Cₖ | x)
#
# </div>
#
# </div>
#
# <!-- APLICACIONES -->
#
# <div align="center" style="margin-top:70px;">
#
# <h2 style="
# color:#1E3A8A;
# font-size:40px;
# font-family:Arial;
# font-weight:800;
# margin-bottom:30px;
# ">
# 🚀 Aplicaciones Comunes
# </h2>
#
# </div>
#
# <div align="center" style="
# display:flex;
# justify-content:center;
# gap:25px;
# flex-wrap:wrap;
# width:90%;
# margin:auto;
# ">
#
# <div style="
# background:#F8FAFC;
# padding:28px;
# border-radius:20px;
# width:250px;
# box-shadow:0px 4px 14px rgba(0,0,0,0.08);
# ">
#
# <div style="font-size:46px;">📧</div>
#
# <h3 style="
# color:#1E3A8A;
# font-family:Arial;
# margin-top:15px;
# ">
# Filtrado de Spam
# </h3>
#
# <p style="
# color:#475569;
# font-size:18px;
# line-height:1.7;
# ">
# Clasificación automática de correos legítimos y no deseados.
# </p>
#
# </div>
#
# <div style="
# background:#F8FAFC;
# padding:28px;
# border-radius:20px;
# width:250px;
# box-shadow:0px 4px 14px rgba(0,0,0,0.08);
# ">
#
# <div style="font-size:46px;">🩺</div>
#
# <h3 style="
# color:#1E3A8A;
# font-family:Arial;
# margin-top:15px;
# ">
# Diagnóstico Médico
# </h3>
#
# <p style="
# color:#475569;
# font-size:18px;
# line-height:1.7;
# ">
# Estimación probabilística de enfermedades a partir de síntomas.
# </p>
#
# </div>
#
# <div style="
# background:#F8FAFC;
# padding:28px;
# border-radius:20px;
# width:250px;
# box-shadow:0px 4px 14px rgba(0,0,0,0.08);
# ">
#
# <div style="font-size:46px;">💬</div>
#
# <h3 style="
# color:#1E3A8A;
# font-family:Arial;
# margin-top:15px;
# ">
# Procesamiento de Texto
# </h3>
#
# <p style="
# color:#475569;
# font-size:18px;
# line-height:1.7;
# ">
# Clasificación de documentos, sentimientos y lenguaje natural.
# </p>
#
# </div>
#
# </div>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.figure(figsize=(10, 6))
img = mpimg.imread('Imagenes/NaiveBayes.png')
plt.imshow(img)
plt.axis('off')  # Opcional: oculta los ejes
plt.show()

# %%
plt.figure(figsize=(10, 6))
img = mpimg.imread('Imagenes/BayesEj_1.png')
plt.imshow(img)
plt.axis('off')  # Opcional: oculta los ejes
plt.show()

# %%
plt.figure(figsize=(10, 6))
img = mpimg.imread('Imagenes/BayesEj_2.png')
plt.imshow(img)
plt.axis('off')  # Opcional: oculta los ejes
plt.show()

# %%
plt.figure(figsize=(10, 6))
img = mpimg.imread('Imagenes/BayesEj_3.png')
plt.imshow(img)
plt.axis('off')  # Opcional: oculta los ejes
plt.show()

# %%
# 1. Importamos librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# 2. Cargamos el dataset
data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# Separar X (características) e y (etiqueta) usando .drop()
X = df.drop('target', axis=1)
y = df['target']
#X.columns

# %%
# 2-1 Agregar ruido gaussiano: media=0, std=0.5
np.random.seed(42)  # para reproducibilidad
noise = np.random.normal(loc=0.0, scale=2, size=X.shape)
X = X + noise  # nueva base con ruido

# %%
# 3. Exploramos brevemente los datos

pairplot = sns.pairplot(df[['alcohol', 'malic_acid', 'ash','proanthocyanins', 'color_intensity','target']], hue='target')
plt.suptitle("Distribución de características (primeras 3)", y=1.02)
plt.show()

# %%
# 4. Dividimos en train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# 5. Creamos y entrenamos el modelo
model = GaussianNB()
model.fit(X_train, y_train)

# %%
# 6. Hacemos predicciones
y_pred = model.predict(X_test)

# %%
# 7. Evaluamos el modelo
print("📊 Reporte de clasificación:\n")
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm, display_labels=data.target_names).plot(cmap="Blues")
plt.title("Matriz de confusión - Naive Bayes")
plt.show()

# %%
# predicción Manual:

nuevo_dato = np.array([[1.52234283e+01, 1.43347140e+00, 3.72537708e+00, 1.86460597e+01,
       1.26531693e+02, 2.33172609e+00, 6.21842563e+00, 1.81486946e+00,
       1.35105123e+00, 6.72512009e+00, 1.13164614e-01, 2.98854049e+00,
       1.06548392e+03]])

# %%
model.predict(nuevo_dato)

# %%
# Para quitar la advertencia:

# Usar los mismos nombres de las columnas con las que se entrenó
nuevo_dato_df = pd.DataFrame(nuevo_dato, columns=X.columns)

prediccion = model.predict(nuevo_dato_df)
print("Predicción:", prediccion)

# %% [markdown]
# ## Seleccionamos solo 2 características para poder graficar

# %%
X_vis = X.iloc[:, [0, 2]]  # 'alcohol' y 'ash'
X_vis_train, X_vis_test, y_vis_train, y_vis_test = train_test_split(X_vis, y, test_size=0.3, random_state=42)

# %%
# Entrenamos un nuevo modelo con sólo esas 2 características
model_vis = GaussianNB()
model_vis.fit(X_vis_train, y_vis_train)

# %%
# Crear una malla de puntos para graficar la frontera de decisión
h = 0.1  # paso de la malla
x_min, x_max = X_vis_train.iloc[:, 0].min() - 1, X_vis_train.iloc[:, 0].max() + 1
y_min, y_max = X_vis_train.iloc[:, 1].min() - 1, X_vis_train.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %%
# Predecimos sobre todos los puntos del meshgrid
Z = model_vis.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
# Para eliminar la advertencia:

# Crear un DataFrame con nombres de columnas antes de predecir
grid_points = pd.DataFrame(np.c_[xx.ravel(), yy.ravel()], columns=X_vis.columns)
Z = model_vis.predict(grid_points)
Z = Z.reshape(xx.shape)

# %%
# Graficamos
plt.figure(figsize=(8,6))
plt.contourf(xx, yy, Z, cmap=plt.cm.Pastel2, alpha=0.6)
sns.scatterplot(x=X_vis_train.iloc[:, 0], y=X_vis_train.iloc[:, 1], hue=y_vis_train, palette='Set1', edgecolor='k')
plt.xlabel("Alcohol")
plt.ylabel("Ash")
plt.title("Frontera de decisión - Naive Bayes (2 características)")
plt.grid(True)
plt.show()

# %%
# Predicciones sobre el conjunto de prueba
y_pred_vis = model_vis.predict(X_vis_test)

# Matriz de confusión
cm = confusion_matrix( y_vis_test, y_pred_vis)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title("Matriz de Confusión - Naive Bayes (2 características)")
plt.grid(False)
plt.show()

# Reporte de clasificación
print("📊 Reporte de clasificación:")
print(classification_report( y_vis_test, y_pred_vis))

# %%
# Usar los mismos nombres de las columnas
nuevo_dato_df = pd.DataFrame(nuevo_dato, columns=X.columns)

prediccion = model.predict(nuevo_dato_df)
print("Predicción:", prediccion)

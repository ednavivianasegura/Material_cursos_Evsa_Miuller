# %% [markdown]
# <a href="https://colab.research.google.com/github/ednavivianasegura/Curso_ML_Python/blob/main/Modulo1_b/02_pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# %%html

<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/tabler-icons.min.css">
<style>
  @import url('https://fonts.googleapis.com/css2?family=Source+Code+Pro:wght@400;500&family=DM+Sans:wght@300;400;500;600&display=swap');
  .nb-cell{font-family:'DM Sans',sans-serif;padding:1.2rem 0;max-width:860px;}
  .nb-title{font-size:20px;font-weight:600;color:#1E3A8A;margin:0 0 .9rem 0;letter-spacing:-.3px;}
  .nb-divider{height:2px;background:linear-gradient(90deg,#1E3A8A 0%,#475569 60%,transparent 100%);margin-bottom:1.25rem;border:none;}
  .nb-body-box{font-size:13.5px;color:#1e293b;line-height:1.7;margin-bottom:1rem;padding:10px 14px;background:#F8FAFF;border-left:3px solid #1E3A8A;border-radius:0 6px 6px 0;}
  code.ic{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#EFF6FF;color:#1E3A8A;padding:2px 7px;border-radius:4px;border:1px solid #BFDBFE;white-space:nowrap;}
  code.ic-g{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#F0FDF4;color:#0F766E;padding:2px 7px;border-radius:4px;border:1px solid #99F6E4;white-space:nowrap;}
  .code-block{background:#0f172a;border-radius:8px;overflow:hidden;margin-top:.5rem;}
  .code-header{display:flex;align-items:center;justify-content:space-between;padding:7px 14px;background:#1e293b;border-bottom:1px solid #334155;}
  .code-lang{font-family:'Source Code Pro',monospace;font-size:11px;color:#64748b;letter-spacing:.5px;text-transform:uppercase;}
  .dots{display:flex;gap:5px;}.dot{width:9px;height:9px;border-radius:50%;}
  .dot-r{background:#ef4444;}.dot-y{background:#f59e0b;}.dot-g{background:#22c55e;}
  pre.cc{padding:14px 18px;font-family:'Source Code Pro',monospace;font-size:13px;line-height:1.7;color:#e2e8f0;margin:0;white-space:pre;}
  .kw{color:#7dd3fc;}.mod{color:#a5f3fc;}.al{color:#86efac;}.cm{color:#94A3B8;font-style:italic;}
  .fn{color:#c4b5fd;}.st{color:#86efac;}.num{color:#fcd34d;}.op{color:#f9a8d4;}
  .nb-note{display:flex;gap:10px;align-items:flex-start;background:#F0FDF4;border-left:3px solid #0F766E;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .nb-note-text{font-size:13px;color:#0f766e;line-height:1.6;}
  .warn-box{display:flex;align-items:flex-start;gap:10px;background:#FFF7ED;border-left:3px solid #F59E0B;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .warn-text{font-size:13px;color:#92400E;line-height:1.6;}
  .table-wrap{border-radius:8px;overflow:hidden;border:1px solid rgba(0,0,0,.08);box-shadow:0 2px 8px rgba(0,0,0,.05);}
  .ref-table{width:100%;border-collapse:collapse;font-size:13px;}
  .ref-table thead tr{background:#1E3A8A;color:#fff;}
  .ref-table thead th{padding:10px 16px;text-align:left;font-weight:500;font-size:11px;letter-spacing:.8px;text-transform:uppercase;}
  .ref-table thead th:first-child{border-radius:8px 0 0 0;width:30%;}
  .ref-table thead th:last-child{border-radius:0 8px 0 0;}
  .ref-table tbody tr:nth-child(odd){background:#F8FAFF;}
  .ref-table tbody tr:nth-child(even){background:#fff;}
  .ref-table tbody tr:hover{background:#EFF6FF;}
  .ref-table tbody td{padding:9px 16px;border-bottom:.5px solid rgba(0,0,0,.06);color:#1e293b;vertical-align:middle;}
  .ref-table tbody tr:last-child td{border-bottom:none;}
  .ref-table tbody tr:last-child td:first-child{border-radius:0 0 0 8px;}
  .ref-table tbody tr:last-child td:last-child{border-radius:0 0 8px 0;}
  .desc{font-size:13px;color:#475569;line-height:1.5;}
  .desc strong{color:#1E3A8A;font-weight:600;}
  .tip{position:relative;display:inline-block;}
  .tip .tt{visibility:hidden;opacity:0;background:#1e293b;color:#e2e8f0;font-family:'DM Sans',sans-serif;font-size:12px;line-height:1.5;border-radius:6px;padding:7px 11px;position:absolute;z-index:999;left:0;top:calc(100% + 6px);white-space:normal;max-width:300px;box-shadow:0 4px 12px rgba(0,0,0,.2);transition:opacity .18s ease;pointer-events:none;}
  .tip .tt::before{content:'';position:absolute;bottom:100%;left:14px;border:5px solid transparent;border-bottom-color:#1e293b;}
  .tip:hover .tt{visibility:visible;opacity:1;}
  .hint{font-size:11px;color:#94A3B8;margin-top:.6rem;display:flex;align-items:center;gap:5px;}
  .grid2{display:grid;grid-template-columns:1fr 1fr;gap:12px;margin-bottom:12px;}
  .card{background:#fff;border:1px solid rgba(0,0,0,.08);border-radius:10px;padding:1rem;}
  .card-title{font-size:11px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;margin-bottom:.6rem;padding-bottom:.5rem;border-bottom:.5px solid rgba(0,0,0,.07);}
  .card-body{font-size:13px;color:#1e293b;line-height:1.6;}
</style>

<div class="nb-cell" style="padding:1.5rem 0 2rem;">
  <div style="display:flex;align-items:flex-start;justify-content:space-between;gap:24px;margin-bottom:1.5rem;padding-bottom:1.25rem;border-bottom:2px solid #1E3A8A;">
    <div style="flex:1;">
      <span style="display:inline-block;font-size:10px;font-weight:600;letter-spacing:1.2px;text-transform:uppercase;color:#0F766E;background:#CCFBF1;border:1px solid #5EEAD4;padding:3px 10px;border-radius:20px;margin-bottom:8px;">Plan de Formación PDI/PAS 2026</span>
      <div style="font-size:11px;color:#475569;letter-spacing:.6px;text-transform:uppercase;margin-bottom:6px;">Formación para la investigación</div>
      <div style="font-size:11px;font-style:italic;color:#475569;margin-bottom:4px;">Módulo 2 — Pandas 3</div>
      <h1 style="font-size:24px;font-weight:700;color:#1E3A8A;line-height:1.2;margin:0;">Python: Programación de IA</h1>
    </div>
    <div style="display:flex;flex-direction:column;align-items:center;gap:6px;flex-shrink:0;">
      <img src="https://github.com/ednavivianasegura/AccesoImages/blob/main/logoUR.png?raw=true" alt="Logo UR" style="width:72px;height:auto;">
      <div style="font-size:9px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;text-align:center;line-height:1.4;">Universidad<br>de La Rioja</div>
    </div>
  </div>
  <div style="display:grid;grid-template-columns:1fr 1fr;gap:14px;margin-bottom:14px;">
    <div style="background:#fff;border:1px solid rgba(0,0,0,.1);border-radius:10px;padding:1rem;">
      <div style="font-size:10px;font-weight:600;letter-spacing:1px;text-transform:uppercase;color:#475569;margin-bottom:.7rem;padding-bottom:.5rem;border-bottom:1px solid rgba(0,0,0,.07);"><i class="ti ti-list-check" style="font-size:13px;color:#1E3A8A;vertical-align:-1px;"></i> &nbsp;Contenidos</div>
      <div style="display:flex;flex-direction:column;gap:5px;">
        <div style="font-size:12.5px;color:#1e293b;display:flex;align-items:center;gap:8px;"><span style="display:inline-flex;align-items:center;justify-content:center;width:18px;height:18px;border-radius:50%;background:#EFF6FF;border:1px solid #BFDBFE;color:#1E3A8A;font-size:10px;font-weight:600;flex-shrink:0;">1</span>map(), applymap() y apply()</div>
        <div style="font-size:12.5px;color:#1e293b;display:flex;align-items:center;gap:8px;"><span style="display:inline-flex;align-items:center;justify-content:center;width:18px;height:18px;border-radius:50%;background:#EFF6FF;border:1px solid #BFDBFE;color:#1E3A8A;font-size:10px;font-weight:600;flex-shrink:0;">2</span>Valores nulos — NaN</div>
        <div style="font-size:12.5px;color:#1e293b;display:flex;align-items:center;gap:8px;"><span style="display:inline-flex;align-items:center;justify-content:center;width:18px;height:18px;border-radius:50%;background:#EFF6FF;border:1px solid #BFDBFE;color:#1E3A8A;font-size:10px;font-weight:600;flex-shrink:0;">3</span>groupby() y funciones agregadas</div>
      </div>
    </div>
    <div style="background:#fff;border:1px solid rgba(0,0,0,.1);border-radius:10px;padding:1rem;">
      <div style="font-size:10px;font-weight:600;letter-spacing:1px;text-transform:uppercase;color:#475569;margin-bottom:.7rem;padding-bottom:.5rem;border-bottom:1px solid rgba(0,0,0,.07);"><i class="ti ti-target" style="font-size:13px;color:#1E3A8A;vertical-align:-1px;"></i> &nbsp;Objetivo</div>
      <div style="font-size:12.5px;color:#1e293b;line-height:1.6;">Aplicar transformaciones avanzadas sobre Series y DataFrames, gestionar valores nulos y agrupar datos para obtener estadísticas resumidas.</div>
    </div>
  </div>
  <div style="display:flex;align-items:center;justify-content:space-between;padding:9px 14px;background:#F8FAFF;border:1px solid #BFDBFE;border-radius:8px;font-size:11px;color:#94A3B8;">
    <span><i class="ti ti-school" style="font-size:12px;color:#1E3A8A;"></i> Universidad de La Rioja — Logroño, La Rioja</span>
    <span><i class="ti ti-calendar" style="font-size:12px;color:#1E3A8A;"></i> Plan de Formación PDI/PAS 2026</span>
  </div>
</div>
# Out:
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/tabler-icons.min.css">
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Source+Code+Pro:wght@400;500&family=DM+Sans:wght@300;400;500;600&display=swap');
#   .nb-cell{font-family:'DM Sans',sans-serif;padding:1.2rem 0;max-width:860px;}
#   .nb-title{font-size:20px;font-weight:600;color:#1E3A8A;margin:0 0 .9rem 0;letter-spacing:-.3px;}
#   .nb-divider{height:2px;background:linear-gradient(90deg,#1E3A8A 0%,#475569 60%,transparent 100%);margin-bottom:1.25rem;border:none;}
#   .nb-body-box{font-size:13.5px;color:#1e293b;line-height:1.7;margin-bottom:1rem;padding:10px 14px;background:#F8FAFF;border-left:3px solid #1E3A8A;border-radius:0 6px 6px 0;}
#   code.ic{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#EFF6FF;color:#1E3A8A;padding:2px 7px;border-radius:4px;border:1px solid #BFDBFE;white-space:nowrap;}
#   code.ic-g{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#F0FDF4;color:#0F766E;padding:2px 7px;border-radius:4px;border:1px solid #99F6E4;white-space:nowrap;}
#   .code-block{background:#0f172a;border-radius:8px;overflow:hidden;margin-top:.5rem;}
#   .code-header{display:flex;align-items:center;justify-content:space-between;padding:7px 14px;background:#1e293b;border-bottom:1px solid #334155;}
#   .code-lang{font-family:'Source Code Pro',monospace;font-size:11px;color:#64748b;letter-spacing:.5px;text-transform:uppercase;}
#   .dots{display:flex;gap:5px;}.dot{width:9px;height:9px;border-radius:50%;}
#   .dot-r{background:#ef4444;}.dot-y{background:#f59e0b;}.dot-g{background:#22c55e;}
#   pre.cc{padding:14px 18px;font-family:'Source Code Pro',monospace;font-size:13px;line-height:1.7;color:#e2e8f0;margin:0;white-space:pre;}
#   .kw{color:#7dd3fc;}.mod{color:#a5f3fc;}.al{color:#86efac;}.cm{color:#94A3B8;font-style:italic;}
#   .fn{color:#c4b5fd;}.st{color:#86efac;}.num{color:#fcd34d;}.op{color:#f9a8d4;}
#   .nb-note{display:flex;gap:10px;align-items:flex-start;background:#F0FDF4;border-left:3px solid #0F766E;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
#   .nb-note-text{font-size:13px;color:#0f766e;line-height:1.6;}
#   .warn-box{display:flex;align-items:flex-start;gap:10px;background:#FFF7ED;border-left:3px solid #F59E0B;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
#   .warn-text{font-size:13px;color:#92400E;line-height:1.6;}
#   .table-wrap{border-radius:8px;overflow:hidden;border:1px solid rgba(0,0,0,.08);box-shadow:0 2px 8px rgba(0,0,0,.05);}
#   .ref-table{width:100%;border-collapse:collapse;font-size:13px;}
#   .ref-table thead tr{background:#1E3A8A;color:#fff;}
#   .ref-table thead th{padding:10px 16px;text-align:left;font-weight:500;font-size:11px;letter-spacing:.8px;text-transform:uppercase;}
#   .ref-table thead th:first-child{border-radius:8px 0 0 0;width:30%;}
#   .ref-table thead th:last-child{border-radius:0 8px 0 0;}
#   .ref-table tbody tr:nth-child(odd){background:#F8FAFF;}
#   .ref-table tbody tr:nth-child(even){background:#fff;}
#   .ref-table tbody tr:hover{background:#EFF6FF;}
#   .ref-table tbody td{padding:9px 16px;border-bottom:.5px solid rgba(0,0,0,.06);color:#1e293b;vertical-align:middle;}
#   .ref-table tbody tr:last-child td{border-bottom:none;}
#   .ref-table tbody tr:last-child td:first-child{border-radius:0 0 0 8px;}
#   .ref-table tbody tr:last-child td:last-child{border-radius:0 0 8px 0;}
#   .desc{font-size:13px;color:#475569;line-height:1.5;}
#   .desc strong{color:#1E3A8A;font-weight:600;}
#   .tip{position:relative;display:inline-block;}
#   .tip .tt{visibility:hidden;opacity:0;background:#1e293b;color:#e2e8f0;font-family:'DM Sans',sans-serif;font-size:12px;line-height:1.5;border-radius:6px;padding:7px 11px;position:absolute;z-index:999;left:0;top:calc(100% + 6px);white-space:normal;max-width:300px;box-shadow:0 4px 12px rgba(0,0,0,.2);transition:opacity .18s ease;pointer-events:none;}
#   .tip .tt::before{content:'';position:absolute;bottom:100%;left:14px;border:5px solid transparent;border-bottom-color:#1e293b;}
#   .tip:hover .tt{visibility:visible;opacity:1;}
#   .hint{font-size:11px;color:#94A3B8;margin-top:.6rem;display:flex;align-items:center;gap:5px;}
#   .grid2{display:grid;grid-template-columns:1fr 1fr;gap:12px;margin-bottom:12px;}
#   .card{background:#fff;border:1px solid rgba(0,0,0,.08);border-radius:10px;padding:1rem;}
#   .card-title{font-size:11px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;margin-bottom:.6rem;padding-bottom:.5rem;border-bottom:.5px solid rgba(0,0,0,.07);}
#   .card-body{font-size:13px;color:#1e293b;line-height:1.6;}
# </style>
#
# <div class="nb-cell" style="padding:1.5rem 0 2rem;">
#   <div style="display:flex;align-items:flex-start;justify-content:space-between;gap:24px;margin-bottom:1.5rem;padding-bottom:1.25rem;border-bottom:2px solid #1E3A8A;">
#     <div style="flex:1;">
#       <span style="display:inline-block;font-size:10px;font-weight:600;letter-spacing:1.2px;text-transform:uppercase;color:#0F766E;background:#CCFBF1;border:1px solid #5EEAD4;padding:3px 10px;border-radius:20px;margin-bottom:8px;">Plan de Formación PDI/PAS 2026</span>
#       <div style="font-size:11px;color:#475569;letter-spacing:.6px;text-transform:uppercase;margin-bottom:6px;">Formación para la investigación</div>
#       <div style="font-size:11px;font-style:italic;color:#475569;margin-bottom:4px;">Módulo 2 — Pandas 3</div>
#       <h1 style="font-size:24px;font-weight:700;color:#1E3A8A;line-height:1.2;margin:0;">Python: Programación de IA</h1>
#     </div>
#     <div style="display:flex;flex-direction:column;align-items:center;gap:6px;flex-shrink:0;">
#       <img src="https://github.com/ednavivianasegura/AccesoImages/blob/main/logoUR.png?raw=true" alt="Logo UR" style="width:72px;height:auto;">
#       <div style="font-size:9px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;text-align:center;line-height:1.4;">Universidad<br>de La Rioja</div>
#     </div>
#   </div>
#   <div style="display:grid;grid-template-columns:1fr 1fr;gap:14px;margin-bottom:14px;">
#     <div style="background:#fff;border:1px solid rgba(0,0,0,.1);border-radius:10px;padding:1rem;">
#       <div style="font-size:10px;font-weight:600;letter-spacing:1px;text-transform:uppercase;color:#475569;margin-bottom:.7rem;padding-bottom:.5rem;border-bottom:1px solid rgba(0,0,0,.07);"><i class="ti ti-list-check" style="font-size:13px;color:#1E3A8A;vertical-align:-1px;"></i> &nbsp;Contenidos</div>
#       <div style="display:flex;flex-direction:column;gap:5px;">
#         <div style="font-size:12.5px;color:#1e293b;display:flex;align-items:center;gap:8px;"><span style="display:inline-flex;align-items:center;justify-content:center;width:18px;height:18px;border-radius:50%;background:#EFF6FF;border:1px solid #BFDBFE;color:#1E3A8A;font-size:10px;font-weight:600;flex-shrink:0;">1</span>map(), applymap() y apply()</div>
#         <div style="font-size:12.5px;color:#1e293b;display:flex;align-items:center;gap:8px;"><span style="display:inline-flex;align-items:center;justify-content:center;width:18px;height:18px;border-radius:50%;background:#EFF6FF;border:1px solid #BFDBFE;color:#1E3A8A;font-size:10px;font-weight:600;flex-shrink:0;">2</span>Valores nulos — NaN</div>
#         <div style="font-size:12.5px;color:#1e293b;display:flex;align-items:center;gap:8px;"><span style="display:inline-flex;align-items:center;justify-content:center;width:18px;height:18px;border-radius:50%;background:#EFF6FF;border:1px solid #BFDBFE;color:#1E3A8A;font-size:10px;font-weight:600;flex-shrink:0;">3</span>groupby() y funciones agregadas</div>
#       </div>
#     </div>
#     <div style="background:#fff;border:1px solid rgba(0,0,0,.1);border-radius:10px;padding:1rem;">
#       <div style="font-size:10px;font-weight:600;letter-spacing:1px;text-transform:uppercase;color:#475569;margin-bottom:.7rem;padding-bottom:.5rem;border-bottom:1px solid rgba(0,0,0,.07);"><i class="ti ti-target" style="font-size:13px;color:#1E3A8A;vertical-align:-1px;"></i> &nbsp;Objetivo</div>
#       <div style

# %%
import numpy as np
import pandas as pd

# %%
# !git clone https://github.com/ednavivianasegura/Curso_ML_Python.git
# Out:
# fatal: destination path 'Curso_ML_Python' already exists and is not an empty directory.

# %%
import os
os.chdir("/content/Curso_ML_Python/Modulo1_b")

# %%
df = pd.read_csv("Data/titanic_1.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4082/1324694133.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("Data/titanic_1.csv")
#       2 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/titanic_1.csv'

# %%
# @title
# %%html

<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/tabler-icons.min.css">
<style>
  @import url('https://fonts.googleapis.com/css2?family=Source+Code+Pro:wght@400;500&family=DM+Sans:wght@300;400;500;600&display=swap');
  .nb-cell{font-family:'DM Sans',sans-serif;padding:1.2rem 0;max-width:860px;}
  .nb-title{font-size:20px;font-weight:600;color:#1E3A8A;margin:0 0 .9rem 0;letter-spacing:-.3px;}
  .nb-divider{height:2px;background:linear-gradient(90deg,#1E3A8A 0%,#475569 60%,transparent 100%);margin-bottom:1.25rem;border:none;}
  .nb-body-box{font-size:13.5px;color:#1e293b;line-height:1.7;margin-bottom:1rem;padding:10px 14px;background:#F8FAFF;border-left:3px solid #1E3A8A;border-radius:0 6px 6px 0;}
  code.ic{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#EFF6FF;color:#1E3A8A;padding:2px 7px;border-radius:4px;border:1px solid #BFDBFE;white-space:nowrap;}
  code.ic-g{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#F0FDF4;color:#0F766E;padding:2px 7px;border-radius:4px;border:1px solid #99F6E4;white-space:nowrap;}
  .code-block{background:#0f172a;border-radius:8px;overflow:hidden;margin-top:.5rem;}
  .code-header{display:flex;align-items:center;justify-content:space-between;padding:7px 14px;background:#1e293b;border-bottom:1px solid #334155;}
  .code-lang{font-family:'Source Code Pro',monospace;font-size:11px;color:#64748b;letter-spacing:.5px;text-transform:uppercase;}
  .dots{display:flex;gap:5px;}.dot{width:9px;height:9px;border-radius:50%;}
  .dot-r{background:#ef4444;}.dot-y{background:#f59e0b;}.dot-g{background:#22c55e;}
  pre.cc{padding:14px 18px;font-family:'Source Code Pro',monospace;font-size:13px;line-height:1.7;color:#e2e8f0;margin:0;white-space:pre;}
  .kw{color:#7dd3fc;}.mod{color:#a5f3fc;}.al{color:#86efac;}.cm{color:#94A3B8;font-style:italic;}
  .fn{color:#c4b5fd;}.st{color:#86efac;}.num{color:#fcd34d;}.op{color:#f9a8d4;}
  .nb-note{display:flex;gap:10px;align-items:flex-start;background:#F0FDF4;border-left:3px solid #0F766E;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .nb-note-text{font-size:13px;color:#0f766e;line-height:1.6;}
  .warn-box{display:flex;align-items:flex-start;gap:10px;background:#FFF7ED;border-left:3px solid #F59E0B;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .warn-text{font-size:13px;color:#92400E;line-height:1.6;}
  .table-wrap{border-radius:8px;overflow:hidden;border:1px solid rgba(0,0,0,.08);box-shadow:0 2px 8px rgba(0,0,0,.05);}
  .ref-table{width:100%;border-collapse:collapse;font-size:13px;}
  .ref-table thead tr{background:#1E3A8A;color:#fff;}
  .ref-table thead th{padding:10px 16px;text-align:left;font-weight:500;font-size:11px;letter-spacing:.8px;text-transform:uppercase;}
  .ref-table thead th:first-child{border-radius:8px 0 0 0;width:30%;}
  .ref-table thead th:last-child{border-radius:0 8px 0 0;}
  .ref-table tbody tr:nth-child(odd){background:#F8FAFF;}
  .ref-table tbody tr:nth-child(even){background:#fff;}
  .ref-table tbody tr:hover{background:#EFF6FF;}
  .ref-table tbody td{padding:9px 16px;border-bottom:.5px solid rgba(0,0,0,.06);color:#1e293b;vertical-align:middle;}
  .ref-table tbody tr:last-child td{border-bottom:none;}
  .ref-table tbody tr:last-child td:first-child{border-radius:0 0 0 8px;}
  .ref-table tbody tr:last-child td:last-child{border-radius:0 0 8px 0;}
  .desc{font-size:13px;color:#475569;line-height:1.5;}
  .desc strong{color:#1E3A8A;font-weight:600;}
  .tip{position:relative;display:inline-block;}
  .tip .tt{visibility:hidden;opacity:0;background:#1e293b;color:#e2e8f0;font-family:'DM Sans',sans-serif;font-size:12px;line-height:1.5;border-radius:6px;padding:7px 11px;position:absolute;z-index:999;left:0;top:calc(100% + 6px);white-space:normal;max-width:300px;box-shadow:0 4px 12px rgba(0,0,0,.2);transition:opacity .18s ease;pointer-events:none;}
  .tip .tt::before{content:'';position:absolute;bottom:100%;left:14px;border:5px solid transparent;border-bottom-color:#1e293b;}
  .tip:hover .tt{visibility:visible;opacity:1;}
  .hint{font-size:11px;color:#94A3B8;margin-top:.6rem;display:flex;align-items:center;gap:5px;}
  .grid2{display:grid;grid-template-columns:1fr 1fr;gap:12px;margin-bottom:12px;}
  .card{background:#fff;border:1px solid rgba(0,0,0,.08);border-radius:10px;padding:1rem;}
  .card-title{font-size:11px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;margin-bottom:.6rem;padding-bottom:.5rem;border-bottom:.5px solid rgba(0,0,0,.07);}
  .card-body{font-size:13px;color:#1e293b;line-height:1.6;}
</style>

<div class="nb-cell">
  <h3 class="nb-title">Series.map()</h3>
  <hr class="nb-divider">
  <div class="nb-body-box">
    <code class="ic">.map()</code> aplica una función a <strong>cada elemento</strong> de una Serie.
    Se usa exclusivamente sobre Series (una sola columna), acepta una
    <strong>función lambda</strong> o un <strong>diccionario</strong> como parámetro,
    y <strong>no es in-place</strong> — devuelve una nueva Serie.
  </div>
  <div class="table-wrap">
    <table class="ref-table">
      <thead><tr>
        <th><i class="ti ti-function"></i> &nbsp;Uso</th>
        <th><i class="ti ti-align-left"></i> &nbsp;Descripción</th>
      </tr></thead>
      <tbody>
        <tr>
          <td><span class="tip"><code class="ic">.map(lambda x: f(x))</code><span class="tt">La función recibe cada elemento de la Serie como argumento x y devuelve el valor transformado.</span></span></td>
          <td class="desc">Aplica una <strong>función lambda</strong> elemento a elemento</td>
        </tr>
        <tr>
          <td><span class="tip"><code class="ic">.map(&#123;&quot;a&quot;: 1, &quot;b&quot;: 2&#125;)</code><span class="tt">Equivalente a .replace() con diccionario. Los valores que no están en el diccionario se convierten en NaN.</span></span></td>
          <td class="desc">Mapea valores usando un <strong>diccionario</strong></td>
        </tr>
      </tbody>
    </table>
  </div>
  <div class="code-block">
    <div class="code-header">
      <div class="dots"><div class="dot dot-r"></div><div class="dot dot-y"></div><div class="dot dot-g"></div></div>
      <span class="code-lang">Python</span>
    </div>
    <pre class="cc"><span class="cm"># Raíz cuadrada de cada edad</span>
<span class="al">df</span>[<span class="st">"Age"</span>].map(<span class="kw">lambda</span> x: np.<span class="fn">sqrt</span>(x))

<span class="cm"># Guardar resultado en nueva columna</span>
<span class="al">df</span>[<span class="st">"AgeSQRT"</span>] <span class="op">=</span> <span class="al">df</span>[<span class="st">"Age"</span>].map(<span class="kw">lambda</span> x: np.<span class="fn">sqrt</span>(x))

<span class="cm"># Extraer el apellido del nombre completo</span>
<span class="al">df</span>[<span class="st">"Surname"</span>] <span class="op">=</span> <span class="al">df</span>[<span class="st">"Name"</span>].map(<span class="kw">lambda</span> x: x.<span class="fn">split</span>(<span class="st">","</span>)[<span class="num">0</span>])

<span class="cm"># Condicional dentro del lambda</span>
<span class="al">df</span>[<span class="st">"AgeSQRT"</span>].map(<span class="kw">lambda</span> x: <span class="st">"mayor"</span> <span class="kw">if</span> x <span class="op">&gt;</span> <span class="num">5</span> <span class="kw">else</span> <span class="st">"menor"</span>)

<span class="cm"># Con diccionario — equivalente a .replace()</span>
<span class="al">df</span>[<span class="st">"Sex"</span>].map({{<span class="st">"male"</span>: <span class="st">"H"</span>, <span class="st">"female"</span>: <span class="st">"M"</span>}})</pre>
  </div>
  <div class="nb-note" style="margin-top:.8rem;">
    <i class="ti ti-info-circle" style="color:#0F766E;font-size:15px;flex-shrink:0;margin-top:1px;"></i>
    <span class="nb-note-text">Cuando se usa con diccionario, los valores que <strong>no aparecen como clave</strong> en el diccionario se convierten en <code class="ic">NaN</code>. Si se quiere conservarlos, es preferible usar <code class="ic">.replace()</code>.</span>
  </div>
</div>

# %%
# Raíz cuadrada de la edad
df["Age"].map(lambda x: np.sqrt(x))

# %%
# Multiplicar por 2
df["Age"].map(lambda x: x * 2)

# %%
# Guardar en nueva columna
df["AgeSQRT"] = df["Age"].map(lambda x: np.sqrt(x))
df.head()

# %%
# Extraer apellido
df["Surname"] = df["Name"].map(lambda x: x.split(",")[0])
df.head()

# %%
# Condicional en lambda
df["AgeSQRT"].map(lambda x: "mayor" if x > 5 else "menor")

# %%
# Con diccionario
df["Sex"].map({"male": "H", "female": "M"})

# %%
# Equivalente con .replace()
df["Sex"].replace({"male": "H", "female": "M"})

# %%
# @title
# %%html

<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/tabler-icons.min.css">
<style>
  @import url('https://fonts.googleapis.com/css2?family=Source+Code+Pro:wght@400;500&family=DM+Sans:wght@300;400;500;600&display=swap');
  .nb-cell{font-family:'DM Sans',sans-serif;padding:1.2rem 0;max-width:860px;}
  .nb-title{font-size:20px;font-weight:600;color:#1E3A8A;margin:0 0 .9rem 0;letter-spacing:-.3px;}
  .nb-divider{height:2px;background:linear-gradient(90deg,#1E3A8A 0%,#475569 60%,transparent 100%);margin-bottom:1.25rem;border:none;}
  .nb-body-box{font-size:13.5px;color:#1e293b;line-height:1.7;margin-bottom:1rem;padding:10px 14px;background:#F8FAFF;border-left:3px solid #1E3A8A;border-radius:0 6px 6px 0;}
  code.ic{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#EFF6FF;color:#1E3A8A;padding:2px 7px;border-radius:4px;border:1px solid #BFDBFE;white-space:nowrap;}
  code.ic-g{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#F0FDF4;color:#0F766E;padding:2px 7px;border-radius:4px;border:1px solid #99F6E4;white-space:nowrap;}
  .code-block{background:#0f172a;border-radius:8px;overflow:hidden;margin-top:.5rem;}
  .code-header{display:flex;align-items:center;justify-content:space-between;padding:7px 14px;background:#1e293b;border-bottom:1px solid #334155;}
  .code-lang{font-family:'Source Code Pro',monospace;font-size:11px;color:#64748b;letter-spacing:.5px;text-transform:uppercase;}
  .dots{display:flex;gap:5px;}.dot{width:9px;height:9px;border-radius:50%;}
  .dot-r{background:#ef4444;}.dot-y{background:#f59e0b;}.dot-g{background:#22c55e;}
  pre.cc{padding:14px 18px;font-family:'Source Code Pro',monospace;font-size:13px;line-height:1.7;color:#e2e8f0;margin:0;white-space:pre;}
  .kw{color:#7dd3fc;}.mod{color:#a5f3fc;}.al{color:#86efac;}.cm{color:#94A3B8;font-style:italic;}
  .fn{color:#c4b5fd;}.st{color:#86efac;}.num{color:#fcd34d;}.op{color:#f9a8d4;}
  .nb-note{display:flex;gap:10px;align-items:flex-start;background:#F0FDF4;border-left:3px solid #0F766E;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .nb-note-text{font-size:13px;color:#0f766e;line-height:1.6;}
  .warn-box{display:flex;align-items:flex-start;gap:10px;background:#FFF7ED;border-left:3px solid #F59E0B;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .warn-text{font-size:13px;color:#92400E;line-height:1.6;}
  .table-wrap{border-radius:8px;overflow:hidden;border:1px solid rgba(0,0,0,.08);box-shadow:0 2px 8px rgba(0,0,0,.05);}
  .ref-table{width:100%;border-collapse:collapse;font-size:13px;}
  .ref-table thead tr{background:#1E3A8A;color:#fff;}
  .ref-table thead th{padding:10px 16px;text-align:left;font-weight:500;font-size:11px;letter-spacing:.8px;text-transform:uppercase;}
  .ref-table thead th:first-child{border-radius:8px 0 0 0;width:30%;}
  .ref-table thead th:last-child{border-radius:0 8px 0 0;}
  .ref-table tbody tr:nth-child(odd){background:#F8FAFF;}
  .ref-table tbody tr:nth-child(even){background:#fff;}
  .ref-table tbody tr:hover{background:#EFF6FF;}
  .ref-table tbody td{padding:9px 16px;border-bottom:.5px solid rgba(0,0,0,.06);color:#1e293b;vertical-align:middle;}
  .ref-table tbody tr:last-child td{border-bottom:none;}
  .ref-table tbody tr:last-child td:first-child{border-radius:0 0 0 8px;}
  .ref-table tbody tr:last-child td:last-child{border-radius:0 0 8px 0;}
  .desc{font-size:13px;color:#475569;line-height:1.5;}
  .desc strong{color:#1E3A8A;font-weight:600;}
  .tip{position:relative;display:inline-block;}
  .tip .tt{visibility:hidden;opacity:0;background:#1e293b;color:#e2e8f0;font-family:'DM Sans',sans-serif;font-size:12px;line-height:1.5;border-radius:6px;padding:7px 11px;position:absolute;z-index:999;left:0;top:calc(100% + 6px);white-space:normal;max-width:300px;box-shadow:0 4px 12px rgba(0,0,0,.2);transition:opacity .18s ease;pointer-events:none;}
  .tip .tt::before{content:'';position:absolute;bottom:100%;left:14px;border:5px solid transparent;border-bottom-color:#1e293b;}
  .tip:hover .tt{visibility:visible;opacity:1;}
  .hint{font-size:11px;color:#94A3B8;margin-top:.6rem;display:flex;align-items:center;gap:5px;}
  .grid2{display:grid;grid-template-columns:1fr 1fr;gap:12px;margin-bottom:12px;}
  .card{background:#fff;border:1px solid rgba(0,0,0,.08);border-radius:10px;padding:1rem;}
  .card-title{font-size:11px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;margin-bottom:.6rem;padding-bottom:.5rem;border-bottom:.5px solid rgba(0,0,0,.07);}
  .card-body{font-size:13px;color:#1e293b;line-height:1.6;}
</style>

<div class="nb-cell">
  <h3 class="nb-title">applymap() y apply()</h3>
  <hr class="nb-divider">
  <div class="grid2">
    <div class="card">
      <div class="card-title"><i class="ti ti-table" style="font-size:13px;color:#1E3A8A;vertical-align:-1px;"></i> &nbsp;DataFrame.applymap()</div>
      <div class="card-body">Aplica una función a <strong>cada elemento</strong> de un DataFrame completo o de varias columnas seleccionadas. Solo funciona sobre DataFrames, no sobre Series.</div>
    </div>
    <div class="card">
      <div class="card-title"><i class="ti ti-adjustments" style="font-size:13px;color:#1E3A8A;vertical-align:-1px;"></i> &nbsp;Series/DataFrame.apply()</div>
      <div class="card-body">Más versátil — funciona sobre <strong>Series y DataFrames</strong>. Aplica la función a cada elemento (Series) o a cada columna/fila (DataFrame).</div>
    </div>
  </div>
  <div class="code-block">
    <div class="code-header">
      <div class="dots"><div class="dot dot-r"></div><div class="dot dot-y"></div><div class="dot dot-g"></div></div>
      <span class="code-lang">Python</span>
    </div>
    <pre class="cc"><span class="cm"># applymap: aplica a cada elemento de varias columnas</span>
<span class="al">df</span>[[<span class="st">"Name"</span>, <span class="st">"Sex"</span>]].applymap(<span class="kw">lambda</span> x: x.<span class="fn">lower</span>())

<span class="cm"># apply sobre una Serie</span>
<span class="al">df</span>[<span class="st">"Age"</span>].apply(<span class="kw">lambda</span> x: np.<span class="fn">sqrt</span>(x))

<span class="cm"># apply sobre varias columnas numéricas</span>
<span class="al">df</span>[[<span class="st">"PassengerId"</span>, <span class="st">"Age"</span>]].apply(<span class="kw">lambda</span> x: np.<span class="fn">sqrt</span>(x))</pre>
  </div>
  <div class="table-wrap" style="margin-top:.8rem;">
    <table class="ref-table">
      <thead><tr>
        <th><i class="ti ti-function"></i> &nbsp;Método</th>
        <th>Serie</th>
        <th>DataFrame</th>
        <th><i class="ti ti-align-left"></i> &nbsp;Acepta</th>
      </tr></thead>
      <tbody>
        <tr><td><code class="ic">.map()</code></td><td style="text-align:center;color:#0F766E;">✓</td><td style="text-align:center;color:#ef4444;">✗</td><td class="desc">lambda, dict</td></tr>
        <tr><td><code class="ic">.applymap()</code></td><td style="text-align:center;color:#ef4444;">✗</td><td style="text-align:center;color:#0F766E;">✓</td><td class="desc">lambda</td></tr>
        <tr><td><code class="ic">.apply()</code></td><td style="text-align:center;color:#0F766E;">✓</td><td style="text-align:center;color:#0F766E;">✓</td><td class="desc">lambda, función</td></tr>
      </tbody>
    </table>
  </div>
  <div class="hint"><i class="ti ti-info-circle" style="font-size:13px;"></i> En versiones recientes de pandas, <code class="ic">.applymap()</code> fue renombrado a <code class="ic">.map()</code> a nivel de DataFrame. Ambos nombres funcionan actualmente.</div>
</div>

# %%
# applymap: aplica a cada elemento de varias columnas
df[["Name", "Sex"]].applymap(lambda x: x.lower())

# %%
# map también funciona en versiones recientes de pandas
df[["Name", "Sex"]].map(lambda x: x.upper())

# %%
# apply sobre una Serie
df["Age"].apply(lambda x: np.sqrt(x))

# %%
# apply sobre varias columnas
df[["PassengerId", "Age"]].apply(lambda x: np.sqrt(x))

# %%
# @title
# %%html

<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/tabler-icons.min.css">
<style>
  @import url('https://fonts.googleapis.com/css2?family=Source+Code+Pro:wght@400;500&family=DM+Sans:wght@300;400;500;600&display=swap');
  .nb-cell{font-family:'DM Sans',sans-serif;padding:1.2rem 0;max-width:860px;}
  .nb-title{font-size:20px;font-weight:600;color:#1E3A8A;margin:0 0 .9rem 0;letter-spacing:-.3px;}
  .nb-divider{height:2px;background:linear-gradient(90deg,#1E3A8A 0%,#475569 60%,transparent 100%);margin-bottom:1.25rem;border:none;}
  .nb-body-box{font-size:13.5px;color:#1e293b;line-height:1.7;margin-bottom:1rem;padding:10px 14px;background:#F8FAFF;border-left:3px solid #1E3A8A;border-radius:0 6px 6px 0;}
  code.ic{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#EFF6FF;color:#1E3A8A;padding:2px 7px;border-radius:4px;border:1px solid #BFDBFE;white-space:nowrap;}
  code.ic-g{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#F0FDF4;color:#0F766E;padding:2px 7px;border-radius:4px;border:1px solid #99F6E4;white-space:nowrap;}
  .code-block{background:#0f172a;border-radius:8px;overflow:hidden;margin-top:.5rem;}
  .code-header{display:flex;align-items:center;justify-content:space-between;padding:7px 14px;background:#1e293b;border-bottom:1px solid #334155;}
  .code-lang{font-family:'Source Code Pro',monospace;font-size:11px;color:#64748b;letter-spacing:.5px;text-transform:uppercase;}
  .dots{display:flex;gap:5px;}.dot{width:9px;height:9px;border-radius:50%;}
  .dot-r{background:#ef4444;}.dot-y{background:#f59e0b;}.dot-g{background:#22c55e;}
  pre.cc{padding:14px 18px;font-family:'Source Code Pro',monospace;font-size:13px;line-height:1.7;color:#e2e8f0;margin:0;white-space:pre;}
  .kw{color:#7dd3fc;}.mod{color:#a5f3fc;}.al{color:#86efac;}.cm{color:#94A3B8;font-style:italic;}
  .fn{color:#c4b5fd;}.st{color:#86efac;}.num{color:#fcd34d;}.op{color:#f9a8d4;}
  .nb-note{display:flex;gap:10px;align-items:flex-start;background:#F0FDF4;border-left:3px solid #0F766E;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .nb-note-text{font-size:13px;color:#0f766e;line-height:1.6;}
  .warn-box{display:flex;align-items:flex-start;gap:10px;background:#FFF7ED;border-left:3px solid #F59E0B;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .warn-text{font-size:13px;color:#92400E;line-height:1.6;}
  .table-wrap{border-radius:8px;overflow:hidden;border:1px solid rgba(0,0,0,.08);box-shadow:0 2px 8px rgba(0,0,0,.05);}
  .ref-table{width:100%;border-collapse:collapse;font-size:13px;}
  .ref-table thead tr{background:#1E3A8A;color:#fff;}
  .ref-table thead th{padding:10px 16px;text-align:left;font-weight:500;font-size:11px;letter-spacing:.8px;text-transform:uppercase;}
  .ref-table thead th:first-child{border-radius:8px 0 0 0;width:30%;}
  .ref-table thead th:last-child{border-radius:0 8px 0 0;}
  .ref-table tbody tr:nth-child(odd){background:#F8FAFF;}
  .ref-table tbody tr:nth-child(even){background:#fff;}
  .ref-table tbody tr:hover{background:#EFF6FF;}
  .ref-table tbody td{padding:9px 16px;border-bottom:.5px solid rgba(0,0,0,.06);color:#1e293b;vertical-align:middle;}
  .ref-table tbody tr:last-child td{border-bottom:none;}
  .ref-table tbody tr:last-child td:first-child{border-radius:0 0 0 8px;}
  .ref-table tbody tr:last-child td:last-child{border-radius:0 0 8px 0;}
  .desc{font-size:13px;color:#475569;line-height:1.5;}
  .desc strong{color:#1E3A8A;font-weight:600;}
  .tip{position:relative;display:inline-block;}
  .tip .tt{visibility:hidden;opacity:0;background:#1e293b;color:#e2e8f0;font-family:'DM Sans',sans-serif;font-size:12px;line-height:1.5;border-radius:6px;padding:7px 11px;position:absolute;z-index:999;left:0;top:calc(100% + 6px);white-space:normal;max-width:300px;box-shadow:0 4px 12px rgba(0,0,0,.2);transition:opacity .18s ease;pointer-events:none;}
  .tip .tt::before{content:'';position:absolute;bottom:100%;left:14px;border:5px solid transparent;border-bottom-color:#1e293b;}
  .tip:hover .tt{visibility:visible;opacity:1;}
  .hint{font-size:11px;color:#94A3B8;margin-top:.6rem;display:flex;align-items:center;gap:5px;}
  .grid2{display:grid;grid-template-columns:1fr 1fr;gap:12px;margin-bottom:12px;}
  .card{background:#fff;border:1px solid rgba(0,0,0,.08);border-radius:10px;padding:1rem;}
  .card-title{font-size:11px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;margin-bottom:.6rem;padding-bottom:.5rem;border-bottom:.5px solid rgba(0,0,0,.07);}
  .card-body{font-size:13px;color:#1e293b;line-height:1.6;}
</style>

<div class="nb-cell">
  <h3 class="nb-title">Valores de una Serie y gestión de NaN</h3>
  <hr class="nb-divider">
  <div class="nb-body-box">
    En pandas, los valores nulos se representan como <code class="ic">NaN</code> (<em>Not a Number</em>).
    La mayoría de operaciones los omiten automáticamente, pero es importante saber detectarlos,
    contarlos y decidir si eliminarlos o rellenarlos.
  </div>
  <div class="table-wrap">
    <table class="ref-table">
      <thead><tr>
        <th><i class="ti ti-function"></i> &nbsp;Método / Atributo</th>
        <th><i class="ti ti-align-left"></i> &nbsp;Descripción</th>
      </tr></thead>
      <tbody>
        <tr>
          <td><span class="tip"><code class="ic">.values</code><span class="tt">Devuelve un array de NumPy con los elementos de la columna, sin el índice.</span></span></td>
          <td class="desc">Array NumPy con los elementos de la Serie</td>
        </tr>
        <tr>
          <td><span class="tip"><code class="ic">.value_counts(dropna=False)</code><span class="tt">Por defecto dropna=True omite los NaN. Con dropna=False los incluye en el conteo.</span></span></td>
          <td class="desc">Conteo de valores incluyendo <strong>NaN</strong></td>
        </tr>
        <tr>
          <td><span class="tip"><code class="ic">.isnull()</code><span class="tt">Devuelve una Serie booleana: True donde hay NaN, False donde hay valor. Usar como filtro sobre el DataFrame.</span></span></td>
          <td class="desc">Filtra las filas con <strong>NaN</strong></td>
        </tr>
        <tr>
          <td><span class="tip"><code class="ic">.dropna()</code><span class="tt">Elimina todas las filas que tengan al menos un NaN en cualquier columna. No es in-place por defecto.</span></span></td>
          <td class="desc">Elimina filas con NaN — <strong>no in-place</strong></td>
        </tr>
        <tr>
          <td><span class="tip"><code class="ic">.fillna(valor)</code><span class="tt">Sustituye todos los NaN por el valor indicado. Puede ser 0, la media, la mediana, etc.</span></span></td>
          <td class="desc">Rellena NaN con un valor específico</td>
        </tr>
      </tbody>
    </table>
  </div>
  <div class="code-block">
    <div class="code-header">
      <div class="dots"><div class="dot dot-r"></div><div class="dot dot-y"></div><div class="dot dot-g"></div></div>
      <span class="code-lang">Python</span>
    </div>
    <pre class="cc"><span class="cm"># Array con los valores de la columna</span>
<span class="al">df</span>[<span class="st">"Sex"</span>].values

<span class="cm"># Conteo incluyendo NaN</span>
<span class="al">df</span>[<span class="st">"Age"</span>].value_counts(dropna<span class="op">=</span><span class="kw">False</span>)

<span class="cm"># Filtrar filas con NaN en "Age"</span>
<span class="al">df</span>[<span class="al">df</span>[<span class="st">"Age"</span>].isnull()]

<span class="cm"># Eliminar filas con NaN (no in-place)</span>
<span class="al">df</span>.dropna()

<span class="cm"># Rellenar NaN con 0</span>
<span class="al">df</span>[<span class="st">"Age"</span>] <span class="op">=</span> <span class="al">df</span>[<span class="st">"Age"</span>].fillna(<span class="num">0</span>)</pre>
  </div>
  <div class="warn-box" style="margin-top:.8rem;">
    <i class="ti ti-alert-triangle" style="color:#D97706;font-size:15px;flex-shrink:0;margin-top:1px;"></i>
    <span class="warn-text"><code class="ic">df.dropna(inplace=True)</code> elimina permanentemente las filas con NaN. Asegúrate de que es lo que quieres antes de ejecutarlo.</span>
  </div>
  <div class="hint" style="margin-top:.5rem;"><i class="ti ti-info-circle" style="font-size:13px;"></i> Una buena práctica es rellenar los NaN con la <strong>media o mediana</strong> de la columna: <code class="ic">df["Age"].fillna(df["Age"].mean())</code></div>
</div>

# %%
# Array con los valores de la columna
df["Sex"].values

# %%
# value_counts omite NaN por defecto
df["Age"].value_counts()

# %%
# Incluir NaN en el conteo
df["Age"].value_counts(dropna=False)

# %%
# Filtrar filas con NaN
df[df["Age"].isnull()]

# %%
# Eliminar filas con NaN (no in-place)
df.dropna()

# %%
# Rellenar NaN con 0
df["Age"] = df["Age"].fillna(0)
df.head()

# %%
df = pd.read_excel("Data/Canada.xlsx")
df.head(3)

# %%
df["Continente"].value_counts()

# %%
# @title
# %%html

<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/tabler-icons.min.css">
<style>
  @import url('https://fonts.googleapis.com/css2?family=Source+Code+Pro:wght@400;500&family=DM+Sans:wght@300;400;500;600&display=swap');
  .nb-cell{font-family:'DM Sans',sans-serif;padding:1.2rem 0;max-width:860px;}
  .nb-title{font-size:20px;font-weight:600;color:#1E3A8A;margin:0 0 .9rem 0;letter-spacing:-.3px;}
  .nb-divider{height:2px;background:linear-gradient(90deg,#1E3A8A 0%,#475569 60%,transparent 100%);margin-bottom:1.25rem;border:none;}
  .nb-body-box{font-size:13.5px;color:#1e293b;line-height:1.7;margin-bottom:1rem;padding:10px 14px;background:#F8FAFF;border-left:3px solid #1E3A8A;border-radius:0 6px 6px 0;}
  code.ic{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#EFF6FF;color:#1E3A8A;padding:2px 7px;border-radius:4px;border:1px solid #BFDBFE;white-space:nowrap;}
  code.ic-g{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#F0FDF4;color:#0F766E;padding:2px 7px;border-radius:4px;border:1px solid #99F6E4;white-space:nowrap;}
  .code-block{background:#0f172a;border-radius:8px;overflow:hidden;margin-top:.5rem;}
  .code-header{display:flex;align-items:center;justify-content:space-between;padding:7px 14px;background:#1e293b;border-bottom:1px solid #334155;}
  .code-lang{font-family:'Source Code Pro',monospace;font-size:11px;color:#64748b;letter-spacing:.5px;text-transform:uppercase;}
  .dots{display:flex;gap:5px;}.dot{width:9px;height:9px;border-radius:50%;}
  .dot-r{background:#ef4444;}.dot-y{background:#f59e0b;}.dot-g{background:#22c55e;}
  pre.cc{padding:14px 18px;font-family:'Source Code Pro',monospace;font-size:13px;line-height:1.7;color:#e2e8f0;margin:0;white-space:pre;}
  .kw{color:#7dd3fc;}.mod{color:#a5f3fc;}.al{color:#86efac;}.cm{color:#94A3B8;font-style:italic;}
  .fn{color:#c4b5fd;}.st{color:#86efac;}.num{color:#fcd34d;}.op{color:#f9a8d4;}
  .nb-note{display:flex;gap:10px;align-items:flex-start;background:#F0FDF4;border-left:3px solid #0F766E;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .nb-note-text{font-size:13px;color:#0f766e;line-height:1.6;}
  .warn-box{display:flex;align-items:flex-start;gap:10px;background:#FFF7ED;border-left:3px solid #F59E0B;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .warn-text{font-size:13px;color:#92400E;line-height:1.6;}
  .table-wrap{border-radius:8px;overflow:hidden;border:1px solid rgba(0,0,0,.08);box-shadow:0 2px 8px rgba(0,0,0,.05);}
  .ref-table{width:100%;border-collapse:collapse;font-size:13px;}
  .ref-table thead tr{background:#1E3A8A;color:#fff;}
  .ref-table thead th{padding:10px 16px;text-align:left;font-weight:500;font-size:11px;letter-spacing:.8px;text-transform:uppercase;}
  .ref-table thead th:first-child{border-radius:8px 0 0 0;width:30%;}
  .ref-table thead th:last-child{border-radius:0 8px 0 0;}
  .ref-table tbody tr:nth-child(odd){background:#F8FAFF;}
  .ref-table tbody tr:nth-child(even){background:#fff;}
  .ref-table tbody tr:hover{background:#EFF6FF;}
  .ref-table tbody td{padding:9px 16px;border-bottom:.5px solid rgba(0,0,0,.06);color:#1e293b;vertical-align:middle;}
  .ref-table tbody tr:last-child td{border-bottom:none;}
  .ref-table tbody tr:last-child td:first-child{border-radius:0 0 0 8px;}
  .ref-table tbody tr:last-child td:last-child{border-radius:0 0 8px 0;}
  .desc{font-size:13px;color:#475569;line-height:1.5;}
  .desc strong{color:#1E3A8A;font-weight:600;}
  .tip{position:relative;display:inline-block;}
  .tip .tt{visibility:hidden;opacity:0;background:#1e293b;color:#e2e8f0;font-family:'DM Sans',sans-serif;font-size:12px;line-height:1.5;border-radius:6px;padding:7px 11px;position:absolute;z-index:999;left:0;top:calc(100% + 6px);white-space:normal;max-width:300px;box-shadow:0 4px 12px rgba(0,0,0,.2);transition:opacity .18s ease;pointer-events:none;}
  .tip .tt::before{content:'';position:absolute;bottom:100%;left:14px;border:5px solid transparent;border-bottom-color:#1e293b;}
  .tip:hover .tt{visibility:visible;opacity:1;}
  .hint{font-size:11px;color:#94A3B8;margin-top:.6rem;display:flex;align-items:center;gap:5px;}
  .grid2{display:grid;grid-template-columns:1fr 1fr;gap:12px;margin-bottom:12px;}
  .card{background:#fff;border:1px solid rgba(0,0,0,.08);border-radius:10px;padding:1rem;}
  .card-title{font-size:11px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;margin-bottom:.6rem;padding-bottom:.5rem;border-bottom:.5px solid rgba(0,0,0,.07);}
  .card-body{font-size:13px;color:#1e293b;line-height:1.6;}
</style>

<div class="nb-cell">
  <h3 class="nb-title">DataFrame.groupby()</h3>
  <hr class="nb-divider">
  <div class="nb-body-box">
    <code class="ic">.groupby()</code> agrupa las filas que tienen el mismo valor en una o varias columnas.
    Por sí solo devuelve un objeto de agrupación — siempre debe combinarse con una
    <strong>función agregada</strong> para producir un resultado útil.
  </div>
  <div class="table-wrap">
    <table class="ref-table">
      <thead><tr>
        <th><i class="ti ti-function"></i> &nbsp;Función agregada</th>
        <th><i class="ti ti-align-left"></i> &nbsp;Descripción</th>
      </tr></thead>
      <tbody>
        <tr><td><span class="tip"><code class="ic">.first()</code><span class="tt">Devuelve el primer elemento de cada grupo. Útil para ver un representante de cada categoría.</span></span></td><td class="desc">Primer elemento de cada grupo</td></tr>
        <tr><td><span class="tip"><code class="ic">.last()</code><span class="tt">Devuelve el último elemento de cada grupo.</span></span></td><td class="desc">Último elemento de cada grupo</td></tr>
        <tr><td><span class="tip"><code class="ic">.size()</code><span class="tt">Cuenta el número total de filas por grupo, incluyendo NaN. Distinto de .count().</span></span></td><td class="desc">Número de filas por grupo (incluye NaN)</td></tr>
        <tr><td><span class="tip"><code class="ic">.count()</code><span class="tt">Cuenta solo los valores no nulos por columna en cada grupo.</span></span></td><td class="desc">Número de valores <strong>no NaN</strong> por grupo</td></tr>
        <tr><td><span class="tip"><code class="ic">.sum()</code><span class="tt">Suma todos los valores numéricos de cada grupo.</span></span></td><td class="desc">Suma de cada grupo</td></tr>
        <tr><td><span class="tip"><code class="ic">.max() / .min()</code><span class="tt">Valor máximo o mínimo de cada grupo.</span></span></td><td class="desc">Máximo / mínimo de cada grupo</td></tr>
        <tr><td><span class="tip"><code class="ic">.aggregate([f1, f2])</code><span class="tt">Aplica varias funciones a todas las columnas seleccionadas. El resultado tiene multi-índice en columnas.</span></span></td><td class="desc">Varias funciones a la vez sobre todas las columnas</td></tr>
        <tr><td><span class="tip"><code class="ic">.agg(&#123;col: [f1, f2]&#125;)</code><span class="tt">Permite elegir qué función aplicar a qué columna usando un diccionario.</span></span></td><td class="desc">Funciones distintas por columna</td></tr>
      </tbody>
    </table>
  </div>
  <div class="hint"><i class="ti ti-info-circle" style="font-size:13px;"></i> Pasa el cursor sobre cada función para ver detalles adicionales.</div>
</div>

# %%
# @title
# %%html

<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/tabler-icons.min.css">
<style>
  @import url('https://fonts.googleapis.com/css2?family=Source+Code+Pro:wght@400;500&family=DM+Sans:wght@300;400;500;600&display=swap');
  .nb-cell{font-family:'DM Sans',sans-serif;padding:1.2rem 0;max-width:860px;}
  .nb-title{font-size:20px;font-weight:600;color:#1E3A8A;margin:0 0 .9rem 0;letter-spacing:-.3px;}
  .nb-divider{height:2px;background:linear-gradient(90deg,#1E3A8A 0%,#475569 60%,transparent 100%);margin-bottom:1.25rem;border:none;}
  .nb-body-box{font-size:13.5px;color:#1e293b;line-height:1.7;margin-bottom:1rem;padding:10px 14px;background:#F8FAFF;border-left:3px solid #1E3A8A;border-radius:0 6px 6px 0;}
  code.ic{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#EFF6FF;color:#1E3A8A;padding:2px 7px;border-radius:4px;border:1px solid #BFDBFE;white-space:nowrap;}
  code.ic-g{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#F0FDF4;color:#0F766E;padding:2px 7px;border-radius:4px;border:1px solid #99F6E4;white-space:nowrap;}
  .code-block{background:#0f172a;border-radius:8px;overflow:hidden;margin-top:.5rem;}
  .code-header{display:flex;align-items:center;justify-content:space-between;padding:7px 14px;background:#1e293b;border-bottom:1px solid #334155;}
  .code-lang{font-family:'Source Code Pro',monospace;font-size:11px;color:#64748b;letter-spacing:.5px;text-transform:uppercase;}
  .dots{display:flex;gap:5px;}.dot{width:9px;height:9px;border-radius:50%;}
  .dot-r{background:#ef4444;}.dot-y{background:#f59e0b;}.dot-g{background:#22c55e;}
  pre.cc{padding:14px 18px;font-family:'Source Code Pro',monospace;font-size:13px;line-height:1.7;color:#e2e8f0;margin:0;white-space:pre;}
  .kw{color:#7dd3fc;}.mod{color:#a5f3fc;}.al{color:#86efac;}.cm{color:#94A3B8;font-style:italic;}
  .fn{color:#c4b5fd;}.st{color:#86efac;}.num{color:#fcd34d;}.op{color:#f9a8d4;}
  .nb-note{display:flex;gap:10px;align-items:flex-start;background:#F0FDF4;border-left:3px solid #0F766E;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .nb-note-text{font-size:13px;color:#0f766e;line-height:1.6;}
  .warn-box{display:flex;align-items:flex-start;gap:10px;background:#FFF7ED;border-left:3px solid #F59E0B;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .warn-text{font-size:13px;color:#92400E;line-height:1.6;}
  .table-wrap{border-radius:8px;overflow:hidden;border:1px solid rgba(0,0,0,.08);box-shadow:0 2px 8px rgba(0,0,0,.05);}
  .ref-table{width:100%;border-collapse:collapse;font-size:13px;}
  .ref-table thead tr{background:#1E3A8A;color:#fff;}
  .ref-table thead th{padding:10px 16px;text-align:left;font-weight:500;font-size:11px;letter-spacing:.8px;text-transform:uppercase;}
  .ref-table thead th:first-child{border-radius:8px 0 0 0;width:30%;}
  .ref-table thead th:last-child{border-radius:0 8px 0 0;}
  .ref-table tbody tr:nth-child(odd){background:#F8FAFF;}
  .ref-table tbody tr:nth-child(even){background:#fff;}
  .ref-table tbody tr:hover{background:#EFF6FF;}
  .ref-table tbody td{padding:9px 16px;border-bottom:.5px solid rgba(0,0,0,.06);color:#1e293b;vertical-align:middle;}
  .ref-table tbody tr:last-child td{border-bottom:none;}
  .ref-table tbody tr:last-child td:first-child{border-radius:0 0 0 8px;}
  .ref-table tbody tr:last-child td:last-child{border-radius:0 0 8px 0;}
  .desc{font-size:13px;color:#475569;line-height:1.5;}
  .desc strong{color:#1E3A8A;font-weight:600;}
  .tip{position:relative;display:inline-block;}
  .tip .tt{visibility:hidden;opacity:0;background:#1e293b;color:#e2e8f0;font-family:'DM Sans',sans-serif;font-size:12px;line-height:1.5;border-radius:6px;padding:7px 11px;position:absolute;z-index:999;left:0;top:calc(100% + 6px);white-space:normal;max-width:300px;box-shadow:0 4px 12px rgba(0,0,0,.2);transition:opacity .18s ease;pointer-events:none;}
  .tip .tt::before{content:'';position:absolute;bottom:100%;left:14px;border:5px solid transparent;border-bottom-color:#1e293b;}
  .tip:hover .tt{visibility:visible;opacity:1;}
  .hint{font-size:11px;color:#94A3B8;margin-top:.6rem;display:flex;align-items:center;gap:5px;}
  .grid2{display:grid;grid-template-columns:1fr 1fr;gap:12px;margin-bottom:12px;}
  .card{background:#fff;border:1px solid rgba(0,0,0,.08);border-radius:10px;padding:1rem;}
  .card-title{font-size:11px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;margin-bottom:.6rem;padding-bottom:.5rem;border-bottom:.5px solid rgba(0,0,0,.07);}
  .card-body{font-size:13px;color:#1e293b;line-height:1.6;}
</style>

<div class="nb-cell">
  <h3 class="nb-title">groupby() — ejemplos</h3>
  <hr class="nb-divider">
  <div class="code-block">
    <div class="code-header">
      <div class="dots"><div class="dot dot-r"></div><div class="dot dot-y"></div><div class="dot dot-g"></div></div>
      <span class="code-lang">Python</span>
    </div>
    <pre class="cc"><span class="cm"># Agrupar por una columna</span>
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>).first()
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>).size()
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>).count()

<span class="cm"># Agrupar por varias columnas</span>
<span class="al">df</span>.groupby([<span class="st">"Continente"</span>, <span class="st">"Tipo de region"</span>]).first()

<span class="cm"># Sumar una columna por grupo</span>
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>)[<span class="num">1980</span>].sum()
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>)[<span class="num">1980</span>].max()

<span class="cm"># Varias columnas a la vez</span>
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>)[[<span class="num">2008</span>, <span class="num">2009</span>, <span class="num">2010</span>]].sum()

<span class="cm"># aggregate: varias funciones sobre todas las columnas</span>
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>)[[<span class="num">2010</span>, <span class="num">2011</span>, <span class="num">2012</span>]].aggregate([min, max, sum])

<span class="cm"># agg con diccionario: función distinta por columna</span>
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>).agg({{
    <span class="num">2010</span>: [<span class="st">"min"</span>, <span class="st">"max"</span>, <span class="st">"sum"</span>, <span class="st">"std"</span>],
    <span class="num">2011</span>: [<span class="st">"min"</span>, <span class="st">"max"</span>, <span class="st">"mean"</span>],
    <span class="num">2012</span>: [<span class="st">"sum"</span>, <span class="st">"median"</span>]
}})

<span class="cm"># as_index=False evita que la columna agrupada sea el índice</span>
<span class="al">df</span>.groupby(<span class="st">"Continente"</span>, as_index<span class="op">=</span><span class="kw">False</span>).agg({{
    <span class="num">2010</span>: [<span class="st">"min"</span>, <span class="st">"max"</span>, <span class="st">"sum"</span>],
    <span class="num">2011</span>: [<span class="st">"min"</span>, <span class="st">"max"</span>],
    <span class="num">2012</span>: [<span class="st">"sum"</span>]
}})</pre>
  </div>
</div>

# %%
df.groupby("Continente").first()

# %%
df.groupby("Continente").size()

# %%
df.groupby(["Continente", "Tipo de region"]).first()

# %%
df.groupby("Continente")[1980].sum()

# %%
# Equivalente con bucle for
dict_cont = {}
for cont, valor in df[["Continente", 1980]].values:
    if cont not in dict_cont.keys():
        dict_cont[cont] = valor
    else:
        dict_cont[cont] = dict_cont[cont] + valor
dict_cont

# %%
df.groupby("Continente")[[2008, 2009, 2010]].sum()

# %%
df.groupby("Continente")[1980].max()

# %%
df.groupby("Continente")[[2010, 2011, 2012]].aggregate([min, max, sum])

# %%
df.groupby("Continente").agg({
    2010: ["min", "max", "sum", "std"],
    2011: ["min", "max", "mean"],
    2012: ["sum", "median"]
})

# %%
df.groupby("Continente", as_index=False).agg({
    2010: ["min", "max", "sum"],
    2011: ["min", "max"],
    2012: ["sum"]
})

# %%
# @title
# %%html

<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@tabler/icons-webfont@latest/tabler-icons.min.css">
<style>
  @import url('https://fonts.googleapis.com/css2?family=Source+Code+Pro:wght@400;500&family=DM+Sans:wght@300;400;500;600&display=swap');
  .nb-cell{font-family:'DM Sans',sans-serif;padding:1.2rem 0;max-width:860px;}
  .nb-title{font-size:20px;font-weight:600;color:#1E3A8A;margin:0 0 .9rem 0;letter-spacing:-.3px;}
  .nb-divider{height:2px;background:linear-gradient(90deg,#1E3A8A 0%,#475569 60%,transparent 100%);margin-bottom:1.25rem;border:none;}
  .nb-body-box{font-size:13.5px;color:#1e293b;line-height:1.7;margin-bottom:1rem;padding:10px 14px;background:#F8FAFF;border-left:3px solid #1E3A8A;border-radius:0 6px 6px 0;}
  code.ic{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#EFF6FF;color:#1E3A8A;padding:2px 7px;border-radius:4px;border:1px solid #BFDBFE;white-space:nowrap;}
  code.ic-g{font-family:'Source Code Pro',monospace;font-size:12.5px;background:#F0FDF4;color:#0F766E;padding:2px 7px;border-radius:4px;border:1px solid #99F6E4;white-space:nowrap;}
  .code-block{background:#0f172a;border-radius:8px;overflow:hidden;margin-top:.5rem;}
  .code-header{display:flex;align-items:center;justify-content:space-between;padding:7px 14px;background:#1e293b;border-bottom:1px solid #334155;}
  .code-lang{font-family:'Source Code Pro',monospace;font-size:11px;color:#64748b;letter-spacing:.5px;text-transform:uppercase;}
  .dots{display:flex;gap:5px;}.dot{width:9px;height:9px;border-radius:50%;}
  .dot-r{background:#ef4444;}.dot-y{background:#f59e0b;}.dot-g{background:#22c55e;}
  pre.cc{padding:14px 18px;font-family:'Source Code Pro',monospace;font-size:13px;line-height:1.7;color:#e2e8f0;margin:0;white-space:pre;}
  .kw{color:#7dd3fc;}.mod{color:#a5f3fc;}.al{color:#86efac;}.cm{color:#94A3B8;font-style:italic;}
  .fn{color:#c4b5fd;}.st{color:#86efac;}.num{color:#fcd34d;}.op{color:#f9a8d4;}
  .nb-note{display:flex;gap:10px;align-items:flex-start;background:#F0FDF4;border-left:3px solid #0F766E;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .nb-note-text{font-size:13px;color:#0f766e;line-height:1.6;}
  .warn-box{display:flex;align-items:flex-start;gap:10px;background:#FFF7ED;border-left:3px solid #F59E0B;border-radius:0 6px 6px 0;padding:10px 14px;margin-top:.8rem;}
  .warn-text{font-size:13px;color:#92400E;line-height:1.6;}
  .table-wrap{border-radius:8px;overflow:hidden;border:1px solid rgba(0,0,0,.08);box-shadow:0 2px 8px rgba(0,0,0,.05);}
  .ref-table{width:100%;border-collapse:collapse;font-size:13px;}
  .ref-table thead tr{background:#1E3A8A;color:#fff;}
  .ref-table thead th{padding:10px 16px;text-align:left;font-weight:500;font-size:11px;letter-spacing:.8px;text-transform:uppercase;}
  .ref-table thead th:first-child{border-radius:8px 0 0 0;width:30%;}
  .ref-table thead th:last-child{border-radius:0 8px 0 0;}
  .ref-table tbody tr:nth-child(odd){background:#F8FAFF;}
  .ref-table tbody tr:nth-child(even){background:#fff;}
  .ref-table tbody tr:hover{background:#EFF6FF;}
  .ref-table tbody td{padding:9px 16px;border-bottom:.5px solid rgba(0,0,0,.06);color:#1e293b;vertical-align:middle;}
  .ref-table tbody tr:last-child td{border-bottom:none;}
  .ref-table tbody tr:last-child td:first-child{border-radius:0 0 0 8px;}
  .ref-table tbody tr:last-child td:last-child{border-radius:0 0 8px 0;}
  .desc{font-size:13px;color:#475569;line-height:1.5;}
  .desc strong{color:#1E3A8A;font-weight:600;}
  .tip{position:relative;display:inline-block;}
  .tip .tt{visibility:hidden;opacity:0;background:#1e293b;color:#e2e8f0;font-family:'DM Sans',sans-serif;font-size:12px;line-height:1.5;border-radius:6px;padding:7px 11px;position:absolute;z-index:999;left:0;top:calc(100% + 6px);white-space:normal;max-width:300px;box-shadow:0 4px 12px rgba(0,0,0,.2);transition:opacity .18s ease;pointer-events:none;}
  .tip .tt::before{content:'';position:absolute;bottom:100%;left:14px;border:5px solid transparent;border-bottom-color:#1e293b;}
  .tip:hover .tt{visibility:visible;opacity:1;}
  .hint{font-size:11px;color:#94A3B8;margin-top:.6rem;display:flex;align-items:center;gap:5px;}
  .grid2{display:grid;grid-template-columns:1fr 1fr;gap:12px;margin-bottom:12px;}
  .card{background:#fff;border:1px solid rgba(0,0,0,.08);border-radius:10px;padding:1rem;}
  .card-title{font-size:11px;font-weight:600;letter-spacing:.8px;text-transform:uppercase;color:#475569;margin-bottom:.6rem;padding-bottom:.5rem;border-bottom:.5px solid rgba(0,0,0,.07);}
  .card-body{font-size:13px;color:#1e293b;line-height:1.6;}
</style>

<div class="nb-cell">
  <h3 class="nb-title">Eliminar multi-índice en columnas</h3>
  <hr class="nb-divider">
  <div class="nb-body-box">
    Cuando se usa <code class="ic">.agg()</code> con varias funciones, pandas genera un
    <strong>multi-índice</strong> en las columnas (ej: <code class="ic">(2010, "min")</code>,
    <code class="ic">(2010, "max")</code>…). Para aplanarlos a nombres simples se puede
    usar una list comprehension que concatene los dos niveles con <code class="ic">_</code>.
  </div>
  <div class="code-block">
    <div class="code-header">
      <div class="dots"><div class="dot dot-r"></div><div class="dot dot-y"></div><div class="dot dot-g"></div></div>
      <span class="code-lang">Python</span>
    </div>
    <pre class="cc"><span class="al">df5</span> <span class="op">=</span> <span class="al">df</span>.groupby(<span class="st">"Continente"</span>).agg({{
    <span class="num">2010</span>: [<span class="st">"min"</span>, <span class="st">"max"</span>, <span class="st">"sum"</span>],
    <span class="num">2011</span>: [<span class="st">"min"</span>, <span class="st">"max"</span>],
    <span class="num">2012</span>: [<span class="st">"sum"</span>]
}})

<span class="cm"># Ver las columnas con multi-índice</span>
<span class="fn">print</span>(<span class="al">df5</span>.columns)

<span class="cm"># Opción A — bucle explícito</span>
columnas <span class="op">=</span> []
<span class="kw">for</span> x <span class="kw">in</span> <span class="al">df5</span>.columns.values:
    columnas.append(<span class="fn">f</span><span class="st">"{{x[0]}}_{{x[1]}}"</span>)
<span class="al">df5</span>.columns <span class="op">=</span> columnas

<span class="cm"># Opción B — list comprehension (más compacta)</span>
<span class="al">df5</span>.columns <span class="op">=</span> [<span class="fn">f</span><span class="st">"{{x[0]}}_{{x[1]}}"</span> <span class="kw">for</span> x <span class="kw">in</span> <span class="al">df5</span>.columns.values]

<span class="al">df5</span>.reset_index()</pre>
  </div>
  <div class="nb-note" style="margin-top:.8rem;">
    <i class="ti ti-info-circle" style="color:#0F766E;font-size:15px;flex-shrink:0;margin-top:1px;"></i>
    <span class="nb-note-text">La <strong>Opción B</strong> es la forma más pythónica y compacta. Ambas producen el mismo resultado: columnas con nombres como <code class="ic">2010_min</code>, <code class="ic">2010_max</code>, <code class="ic">2011_min</code>…</span>
  </div>
</div>

# %%
df5 = df.groupby("Continente").agg({
    2010: ["min", "max", "sum"],
    2011: ["min", "max"],
    2012: ["sum"]
})
print(df5.columns)

# %%
# Aplanar multi-índice con list comprehension
df5.columns = [f"{x[0]}_{x[1]}" for x in df5.columns.values]
df5.reset_index()
